# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>National Leagues</strong></h1>

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install missingno


# work with data in tabular representation
from datetime import time
import pandas as pd
# round the data in the correlation matrix
import numpy as np
import os
import glob


# Modules for data visualization
import seaborn as sns
import missingno as msno

# run a python function file 
# %run ../../src/cleaning/function.py

# ignore DeprecationWarning Error Messages
import warnings
warnings.filterwarnings('ignore')

# %%
# set the path of the external data from the third party source - Kaggle
external_data_path = os.path.join(os.path.pardir, '..', 'data','interim', 'national_leagues')

df = os.path.join(external_data_path, 'national_leagues_2016_2022.csv')

# import dataset
df = pd.read_csv(df, delimiter=',', skipinitialspace = True)

print("The shape of the MATCHES data is (row, column):", str(df.shape))
df.head(3)
# Out:
# The shape of the MATCHES data is (row, column): (16229, 24)
#   league_division  match_date       home_team  away_team  \
# 0              e0  2016-08-13         burnley    swansea
# 1              e0  2016-08-13  crystal palace  west brom
# 2              e0  2016-08-13         everton  tottenham
#
#    full_time_home_team_goals  full_time_away_team_goals full_time_result  \
# 0                          0                          1                a
# 1                          0                          1                a
# 2                          1                          1                d
#
#    half_time_home_team_goals  half_time_away_team_goals half_time_result  \
# 0                        0.0                        0.0                d
# 1                        0.0                        0.0                d
# 2                        1.0                        0.0                h
#
#       referee  home_shots  away_shots  home_shots_on_target  \
# ...

# %%
# print out list of District types
print(f'NUMBER OF DATE CATEGORIES: {df.season.nunique()}; \n\nUNIQUE NAMES OF THE DATE CATEGORIES {df.season.unique()}\n')
# Out:
# NUMBER OF DATE CATEGORIES: 40;
#
# UNIQUE NAMES OF THE DATE CATEGORIES ['../../data/external/national leagues\\season 2016-2017\\e0_english premier league_2016-2017.csv'
#  '../../data/external/national leagues\\season 2016-2017\\e1_efl championship_2016-2017.csv'
#  '../../data/external/national leagues\\season 2016-2017\\e2_efl league one_2016-2017.csv'
#  '../../data/external/national leagues\\season 2016-2017\\e3_efl league two_2016-2017.csv'
#  '../../data/external/national leagues\\season 2017-2018\\e0_english premier league_2017-2018.csv'
#  '../../data/external/national leagues\\season 2017-2018\\e1_efl championship_2017-2018.csv'
#  '../../data/external/national leagues\\season 2017-2018\\e2_efl league one_2017-2018.csv'
#  '../../data/external/national leagues\\season 2017-2018\\e3_efl league two_2017-2018.csv'
#  '../../data/external/national leagues\\season 2018-2019\\e0_english premier league_2018-2019.csv'
# ...

# %%
df['season'] = df.season.apply(lambda x: x.split('_')[-1])
df['season'] = df["season"].str.replace(".csv","")
df
# Out:
#       league_division  match_date       home_team     away_team  \
# 0                  e0  2016-08-13         burnley       swansea
# 1                  e0  2016-08-13  crystal palace     west brom
# 2                  e0  2016-08-13         everton     tottenham
# 3                  e0  2016-08-13            hull     leicester
# 4                  e0  2016-08-13        man city    sunderland
# ...               ...         ...             ...           ...
# 16224             sp2  2022-02-20     fuenlabrada      alcorcon
# 16225             sp2  2022-02-20          burgos        oviedo
# 16226             sp2  2022-02-20          huesca          lugo
# 16227             sp2  2022-02-20        sp gijon  ponferradina
# 16228             sp2  2022-02-20         almeria      mirandes
#
#        full_time_home_team_goals  full_time_away_team_goals full_time_result  \
# 0                              0                          1                a
# ...

# %%
print(f'Shape: {(df.shape)}')
# Out:
# Shape: (16229, 24)

# %% [markdown]
# <a id="3"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong>Save the Intermediate data that has been transformed</strong></h1>

# %%
write_interim_path(df, 'national_leagues_2016_2022.csv', 'national_leagues')
# Out:
# cleaned national_leagues_2016_2022.csv data was successfully saved!
