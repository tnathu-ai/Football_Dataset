# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>National Leagues 2019-2020</strong></h1>

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install missingno


# work with data in tabular representation
from datetime import time
import pandas as pd
# round the data in the correlation matrix
import numpy as np
import os


# Modules for data visualization
import seaborn as sns
import missingno as msno

# run a python file 
# %run ../../src/cleaning/function.py

# ignore DeprecationWarning Error Messages
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: missingno in c:\users\thu\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: seaborn in c:\users\thu\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: numpy in c:\users\thu\anaconda3\lib\site-packages (from missingno) (1.20.3)
# Requirement already satisfied: scipy in c:\users\thu\anaconda3\lib\site-packages (from missingno) (1.7.1)
# Requirement already satisfied: matplotlib in c:\users\thu\anaconda3\lib\site-packages (from missingno) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thu\anaconda3\lib\site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thu\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\thu\anaconda3\lib\site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thu\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thu\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: six in c:\users\thu\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\thu\anaconda3\lib\site-packages (from seaborn->missingno) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\thu\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)

# %% [markdown]
# <a id="1.2"></a>
# # Data Retrieving
# ***
# In order to load data properly, the data in csv file have to be examined carefully. First of all, all the categories are seperated by the "," and strip the extra-whitespaces at the begin by setting "skipinitialspace = True".

# %%
# set the path of the external data from the third party source
external_data_path = os.path.join(os.path.pardir, '', '..', 'data','external', 'National Leagues', 'Season 2019-2020')

# get each specfic file
english_premier_league_df = os.path.join(external_data_path, 'E0_English Premier League_2019-2020.csv')
efl_championship_df = os.path.join(external_data_path, 'E1_EFL Championship_2019-2020.csv')
efl_league_one_df = os.path.join(external_data_path, 'E2_EFL League One_2019-2020.csv')
efl_league_two_df = os.path.join(external_data_path, 'E3_EFL League Two_2019-2020.csv')

# import dataset
english_premier_league_df = pd.read_csv(english_premier_league_df, delimiter=',', skipinitialspace = True)
efl_championship_df = pd.read_csv(efl_championship_df, delimiter=',', skipinitialspace = True)
efl_league_one_df = pd.read_csv(efl_league_one_df, delimiter=',', skipinitialspace = True)
efl_league_two_df = pd.read_csv(efl_league_two_df, delimiter=',', skipinitialspace = True)

# print out the shape
print("The shape of the E0_English Premier League 2019-2020 dataframe is (row, column):", str(english_premier_league_df.shape))
print("The shape of the E1_EFL Championship 2019-2020 dataframe is (row, column):", str(efl_championship_df.shape))
print("The shape of the E2_EFL League One 2019-2020 dataframe is (row, column):", str(efl_league_one_df.shape))
print("The shape of the E3_EFL League Two 2019-2020 dataframe is (row, column):", str(efl_league_two_df.shape), "\n\n")
# Out:
# The shape of the E0_English Premier League 2019-2020 dataframe is (row, column): (380, 106)
# The shape of the E1_EFL Championship 2019-2020 dataframe is (row, column): (552, 106)
# The shape of the E2_EFL League One 2019-2020 dataframe is (row, column): (400, 106)
# The shape of the E3_EFL League Two 2019-2020 dataframe is (row, column): (440, 106)

# %%
style(english_premier_league_df.head(3))
# Out:
# <style type="text/css">
{
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_4c30f_row0_col13, #T_4c30f_row0_col16, #T_4c30f_row1_col49, #T_4c30f_row1_col51, #T_4c30f_row1_col53, #T_4c30f_row1_col55, #T_4c30f_row1_col59, #T_4c30f_row1_col61, #T_4c30f_row1_col90, #T_4c30f_row1_col92, #T_4c30f_row1_col94, #T_4c30f_row1_col101 {
#   background-color: #e5d8bd;
#   color: #000000;
# }
# #T_4c30f_row0_col15, #T_4c30f_row0_col19, #T_4c30f_row1_col17, #T_4c30f_row2_col56, #T_4c30f_row2_col97 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_4c30f_row1_col25, #T_4c30f_row1_col28, #T_4c30f_row1_col34, #T_4c30f_row1_col37, #T_4c30f_row1_col40, #T_4c30f_row1_col43, #T_4c30f_row1_col46, #T_4c30f_row1_col69, #T_4c30f_row1_col75, #T_4c30f_row1_col78, #T_4c30f_row1_col81, #T_4c30f_row1_col84, #T_4c30f_row1_col87, #T_4c30f_row1_col100 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T_4c30f_row1_col31, #T_4c30f_row1_col66, #T_4c30f_row1_col72, #T_4c30f_row1_col96 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_4c30f_row1_col50, #T_4c30f_row1_col54, #T_4c30f_row1_col58, #T_4c30f_row1_col62, #T_4c30f_row1_col64, #T_4c30f_row1_col89, #T_4c30f_row1_col91, #T_4c30f_row1_col95, #T_4c30f_row1_col103, #T_4c30f_row2_col18, #T_4c30f_row2_col26, #T_4c30f_row2_col29, #T_4c30f_row2_col32, #T_4c30f_row2_col35, #T_4c30f_row2_col38, #T_4c30f_row2_col41, #T_4c30f_row2_col44, #T_4c30f_row2_col47, #T_4c30f_row2_col67, #T_4c30f_row2_col70, #T_4c30f_row2_col73, #T_4c30f_row2_col76, #T_4c30f_row2_col79, #T_4c30f_row2_col82, #T_4c30f_row2_col85, #T_4c30f_row2_col88, #T_4c30f_row2_col102 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# #T_4c30f_row1_col57, #T_4c30f_row1_col63, #T_4c30f_row2_col12, #T_4c30f_row2_col104 {
#   background-color: #fddaec;
#   color: #000000;
# }
# #T_4c30f_row1_col60, #T_4c30f_row1_col93, #T_4c30f_row2_col5 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# </style>
# <table id="T_4c30f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Div</th>
#       <th class="col_heading level0 col1" >Date</th>
#       <th class="col_heading level0 col2" >Time</th>
#       <th class="col_heading level0 col3" >HomeTeam</th>
#       <th class="col_heading level0 col4" >AwayTeam</th>
#       <th class="col_heading level0 col5" >FTHG</th>
#       <th class="col_heading level0 col6" >FTAG</th>
#       <th class="col_heading level0 col7" >FTR</th>
#       <th class="col_heading level0 col8" >HTHG</th>
#       <th class="col_heading level0 col9" >HTAG</th>
#       <th class="col_heading level0 col10" >HTR</th>
#       <th class="col_heading level0 col11" >Referee</th>
#       <th class="col_heading level0 col12" >HS</th>
#       <th class="col_heading level0 col13" >AS</th>
#       <th class="col_heading level0 col14" >HST</th>
#       <th class="col_heading level0 col15" >AST</th>
#       <th class="col_heading level0 col16" >HF</th>
#       <th class="col_heading level0 col17" >AF</th>
#       <th class="col_heading level0 col18" >HC</th>
#       <th class="col_heading level0 col19" >AC</th>
#       <th class="col_heading level0 col20" >HY</th>
#       <th class="col_heading level0 col21" >AY</th>
#       <th class="col_heading level0 col22" >HR</th>
#       <th class="col_heading lev

# %%
style(efl_championship_df.head(3))
# Out:
# <style type="text/css">
{
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_7320c_row0_col26, #T_7320c_row0_col27, #T_7320c_row0_col30, #T_7320c_row0_col33, #T_7320c_row0_col35, #T_7320c_row0_col36, #T_7320c_row0_col38, #T_7320c_row0_col39, #T_7320c_row0_col41, #T_7320c_row0_col42, #T_7320c_row0_col44, #T_7320c_row0_col45, #T_7320c_row0_col47, #T_7320c_row0_col67, #T_7320c_row0_col68, #T_7320c_row0_col73, #T_7320c_row0_col76, #T_7320c_row0_col77, #T_7320c_row0_col79, #T_7320c_row0_col82, #T_7320c_row0_col83, #T_7320c_row0_col85, #T_7320c_row0_col86, #T_7320c_row0_col88, #T_7320c_row0_col98, #T_7320c_row0_col100, #T_7320c_row0_col104, #T_7320c_row1_col19, #T_7320c_row1_col81, #T_7320c_row2_col12, #T_7320c_row2_col51, #T_7320c_row2_col53 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_7320c_row0_col57, #T_7320c_row0_col99, #T_7320c_row0_col101, #T_7320c_row0_col105, #T_7320c_row1_col31, #T_7320c_row1_col40, #T_7320c_row1_col78, #T_7320c_row2_col50 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_7320c_row0_col58, #T_7320c_row0_col62, #T_7320c_row0_col64, #T_7320c_row2_col52, #T_7320c_row2_col91, #T_7320c_row2_col95 {
#   background-color: #fddaec;
#   color: #000000;
# }
# </style>
# <table id="T_7320c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Div</th>
#       <th class="col_heading level0 col1" >Date</th>
#       <th class="col_heading level0 col2" >Time</th>
#       <th class="col_heading level0 col3" >HomeTeam</th>
#       <th class="col_heading level0 col4" >AwayTeam</th>
#       <th class="col_heading level0 col5" >FTHG</th>
#       <th class="col_heading level0 col6" >FTAG</th>
#       <th class="col_heading level0 col7" >FTR</th>
#       <th class="col_heading level0 col8" >HTHG</th>
#       <th class="col_heading level0 col9" >HTAG</th>
#       <th class="col_heading level0 col10" >HTR</th>
#       <th class="col_heading level0 col11" >Referee</th>
#       <th class="col_heading level0 col12" >HS</th>
#       <th class="col_heading level0 col13" >AS</th>
#       <th class="col_heading level0 col14" >HST</th>
#       <th class="col_heading level0 col15" >AST</th>
#       <th class="col_heading level0 col16" >HF</th>
#       <th class="col_heading level0 col17" >AF</th>
#       <th class="col_heading level0 col18" >HC</th>
#       <th class="col_heading level0 col19" >AC</th>
#       <th class="col_heading level0 col20" >HY</th>
#       <th class="col_heading level0 col21" >AY</th>
#       <th class="col_heading level0 col22" >HR</th>
#       <th class="col_heading lev

# %%
style(efl_league_one_df.head(3))
# Out:
# <style type="text/css">
# #T_4e9f2_row0_col5, #T_4e9f2_row0_col16, #T_4e9f2_row0_col48, #T_4e9f2_row0_col50, #T_4e9f2_row0_col52, #T_4e9f2_row0_col98, #T_4e9f2_row0_col99, #T_4e9f2_row0_col102, #T_4e9f2_row0_col103, #T_4e9f2_row0_col105, #T_4e9f2_row2_col6, #T_4e9f2_row2_col31, #T_4e9f2_row2_col60, #T_4e9f2_row2_col61, #T_4e9f2_row2_col62 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T
2_col29, #T_4e9f2_row2_col32, #T_4e9f2_row2_col34, #T_4e9f2_row2_col35, #T_4e9f2_row2_col38, #T_4e9f2_row2_col41, #T_4e9f2_row2_col44, #T_4e9f2_row2_col46, #T_4e9f2_row2_col47, #T_4e9f2_row2_col48, #T_4e9f2_row2_col50, #T_4e9f2_row2_col52, #T_4e9f2_row2_col54, #T_4e9f2_row2_col65, #T_4e9f2_row2_col66, #T_4e9f2_row2_col68, #T_4e9f2_row2_col69, #T_4e9f2_row2_col71, #T_4e9f2_row2_col74, #T_4e9f2_row2_col77, #T_4e9f2_row2_col78, #T_4e9f2_row2_col80, #T_4e9f2_row2_col83, #T_4e9f2_row2_col84, #T_4e9f2_row2_col86, #T_4e9f2_row2_col91, #T_4e9f2_row2_col98, #T_4e9f2_row2_col100, #T_4e9f2_row2_col102, #T_4e9f2_row2_col104 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_4e9f2_row0_col12, #T_4e9f2_row0_col34, #T_4e9f2_row0_col51, #T_4e9f2_row0_col53, #T_4e9f2_row0_col55, #T_4e9f2_row0_col104, #T_4e9f2_row1_col17, #T_4e9f2_row1_col21, #T_4e9f2_row2_col14, #T_4e9f2_row2_col15, #T_4e9f2_row2_col59, #T_4e9f2_row2_col64, #T_4e9f2_row2_col95, #T_4e9f2_row2_col97 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_4e9f2_row0_col13, #T_4e9f2_row0_col24, #T_4e9f2_row0_col27, #T_4e9f2_row0_col101, #T_4e9f2_row1_col18, #T_4e9f2_row1_col19, #T_4e9f2_row2_col63 {
#   background-color: #e5d8bd;
#   color: #000000;
# }
# #T_4e9f2_row0_col26, #T_4e9f2_row0_col32, #T_4e9f2_row0_col44, #T_4e9f2_row0_col49, #T_4e9f2_row0_col100, #T_4e9f2_row2_col58, #T_4e9f2_row2_col90 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# #T_4e9f2_row0_col29, #T_4e9f2_row2_col37, #T_4e9f2_row2_col40 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_4e9f2_row0_col30, #T_4e9f2_row0_col45, #T_4e9f2_row2_col57, #T_4e9f2_row2_col92 {
#   background-color: #fddaec;
#   color: #000000;
# }
# #T_4e9f2_row0_col54, #T_4e9f2_row2_col87, #T_4e9f2_row2_col89, #T_4e9f2_row2_col93, #T_4e9f2_row2_col94, #T_4e9f2_row2_col96 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_4e9f2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Div</th>
#       <th class="col_heading level0 col1" >Date</th>
#       <th class="col_heading level0 col2" >Time</th>
#       <th class="col_heading level0 col3" >HomeTeam</th>
#       <th class="col_heading level0 col4" >AwayTeam</th>
#       <th class="col_heading level0 col5" >FTHG</th>
#       <th class="col_heading level0 col6" >FTAG</th>
#       <th class="col_heading level0 col7" >FTR</th>
#       <th class="col_heading level0 col8" >HTHG</th>
#       <th class="col_heading level0 col9" >HTAG</th>
#       <th class="col_heading level0 col10" >HTR</th>
#       <th class="col_heading level0 col11" >Referee</th>
#       <th class="col_heading level0 col12" >HS</th>
#       <th class="col_heading level0 col13" >AS</th>
#       <th class="col_heading level0 col14" >HST</th>
#       <th class="col_heading level0 col15" >AST</th>
#       <th class="col_heading level0 col16" >HF</th>
#       <th class="col_heading level0 col17" >AF</th>
#       <th class="col_heading level0 col18" >HC</th>
#       <th class="col_heading level0 col19" >AC</th>
#       <th class="col_heading level0 col20" >HY</th>
#       <th class="col_heading level0 col21" >AY</th>
{
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_74642_row0_col8, #T_74642_row0_col14, #T_74642_row0_col37, #T_74642_row0_col46, #T_74642_row0_col69, #T_74642_row0_col71, #T_74642_row0_col74, #T_74642_row0_col79, #T_74642_row0_col83, #T_74642_row0_col85, #T_74642_row0_col86, #T_74642_row0_col88, #T_74642_row1_col29, #T_74642_row2_col20, #T_74642_row2_col94 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T_74642_row0_col12, #T_74642_row0_col72, #T_74642_row1_col27, #T_74642_row1_col100, #T_74642_row2_col78, #T_74642_row2_col93 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_74642_row0_col17, #T_74642_row0_col18, #T_74642_row0_col34, #T_74642_row0_col67, #T_74642_row0_col68, #T_74642_row0_col73, #T_74642_row0_col82, #T_74642_row1_col54, #T_74642_row2_col96 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_74642_row0_col19, #T_74642_row0_col65, #T_74642_row0_col70, #T_74642_row0_col76, #T_74642_row0_col77, #T_74642_row0_col80, #T_74642_row1_col55 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_74642_row0_col36, #T_74642_row0_col42, #T_74642_row0_col63, #T_74642_row0_col81, #T_74642_row1_col16, #T_74642_row1_col104 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# #T_74642_row0_col38, #T_74642_row0_col41, #T_74642_row0_col60, #T_74642_row0_col64, #T_74642_row1_col103, #T_74642_row1_col105 {
#   background-color: #fddaec;
#   color: #000000;
# }
# #T_74642_row1_col35, #T_74642_row1_col53, #T_74642_row1_col99, #T_74642_row1_col101, #T_74642_row2_col95 {
#   background-color: #e5d8bd;
#   color: #000000;
# }
# </style>
# <table id="T_74642_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Div</th>
#       <th class="col_heading level0 col1" >Date</th>
#       <th class="col_heading level0 col2" >Time</th>
#       <th class="col_heading level0 col3" >HomeTeam</th>
#       <th class="col_heading level0 col4" >AwayTeam</th>
#       <th class="col_heading level0 col5" >FTHG</th>
#       <th class="col_heading level0 col6" >FTAG</th>
#       <th class="col_heading level0 col7" >FTR</th>
#       <th class="col_heading level0 col8" >HTHG</th>
#       <th class="col_heading level0 col9" >HTAG</th>
#       <th class="col_heading level0 col10" >HTR</th>
#       <th class="col_heading level0 col11" >Referee</th>
#       <th class="col_heading level0 col12" >HS</th>
#       <th class="col_heading level0 col13" >AS</th>
#       <th class="col_heading level0 col14" >HST</th>
#       <th class="col_heading level0 col15" >AST</th>
#       <th class="col_heading level0 col16" >HF</th>
#       <th class="col_heading level0 col17" >AF</th>
#       <th class="col_heading level0 col18" >HC</th>
#       <th class="col_heading level0 col19" >AC</th>
#       <th class="col_heading level0 col20" >HY</th>
#       <th class="col_heading level0 col21" >AY</th>
#       <th class="col_heading level0 col22" >HR</th>
#       <th class="col_heading lev

# %% [markdown]
# <a id="1.3"></a>
# # [Rename columns base on their abbreviations](http://www.football-data.co.uk/notes.txt)
# ***
# Since these columns are not in SQL naming convention will be more straightforward in later process. We will also analyse the column meaning

# %%
print(f'The list of E0_English Premier League 2019-2020 columns\' names is: {english_premier_league_df.columns.to_list()}\n\n\n')
# Out:
# The list of E0_English Premier League 2019-2020 columns' names is: ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA']

# %%
# rename_cols(english_premier_league_df)
# rename_cols(efl_championship_df)
# rename_cols(efl_league_one_df)
# rename_cols(efl_league_two_df)

# print(f'The list of E0 English Premier League 2019-2020 columns\' names is: {english_premier_league_df.columns.to_list()}\n\n\n')

# %% [markdown]
# # Drop unecessary columns

# %%
english_premier_league_df = english_premier_league_df.drop(['PSCH', 'PSCD', 'PSCA'], axis=1)
efl_championship_df = efl_championship_df.drop(['PSCH', 'PSCD', 'PSCA'], axis=1)
efl_league_one_df = efl_league_one_df.drop(['PSCH', 'PSCD', 'PSCA'], axis=1)
efl_league_two_df = efl_league_two_df.drop(['PSCH', 'PSCD', 'PSCA'], axis=1)

# %%
print(f'The list of E0 English Premier League 2019-2020 columns\' names is: {english_premier_league_df.columns.to_list()}\n\n\n')
# Out:
# The list of E0 English Premier League 2016 2017 columns' names is: ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA']

# %% [markdown]
# # Lower Case the content
#
# In this section we will convert all the string value in the column to uppercase for further processing and keep all the string uniformly format. This will improve the analysis of the data, and also easier to perform any function related to the string.

# %%
# Cast all values inside the dataframe (except the columns' name) into upper case.
english_premier_league_df = english_premier_league_df.applymap(lambda s: s.lower() if type(s) == str else s)
efl_championship_df = efl_championship_df.applymap(lambda s: s.lower() if type(s) == str else s)
efl_league_one_df = efl_league_one_df.applymap(lambda s: s.lower() if type(s) == str else s)
efl_league_two_df = efl_league_two_df.applymap(lambda s: s.lower() if type(s) == str else s)

# %% [markdown]
# # Concat dataframes
# Clear the existing index and reset it in the result by setting the ignore_index option to True.

# %%
df = pd.concat([english_premier_league_df, efl_championship_df, efl_league_one_df, efl_league_two_df], ignore_index=True)
df.head()
# Out:
#   Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  e0  09/08/2019  20:00       liverpool           norwich     4     1   h
# 1  e0  10/08/2019  12:30        west ham          man city     0     5   a
# 2  e0  10/08/2019  15:00     bournemouth  sheffield united     1     1   d
# 3  e0  10/08/2019  15:00         burnley       southampton     3     0   h
# 4  e0  10/08/2019  15:00  crystal palace           everton     0     0   d
#
#    HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 0     4     0   h  m oliver  15  12    7    5   9   9  11   2   0   2   0   0
# 1     0     1   a    m dean   5  14    3    9   6  13   1   1   2   2   0   0
# 2     0     0   d  k friend  13   8    3    3  10  19   3   4   2   1   0   0
# 3     0     0   d   g scott  10  11    4    3   6  12   2   7   0   0   0   0
# 4     0     0   d    j moss   6  10    2    3  16  14   6   2   2   1   0   1
#
#    B365H  B365D  B365A    BWH   BWD    BWA    IWH   IWD    IWA    PSH   PSD  \
vgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  \
# 0  19.18        1.3       3.50    1.34    3.44      1.36      3.76      1.32
# 1   1.26        1.4       3.00    1.43    3.03      1.50      3.22      1.41
# 2   3.96        1.9       1.90    1.94    1.97      1.97      1.98      1.91
# 3   2.88        2.1       1.72    2.19    1.76      2.25      1.78      2.17
# 4   2.23        2.2       1.66    2.22    1.74      2.28      1.77      2.17
#
#    AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0      3.43 -2.25      1.91      1.99   1.94   1.98     1.99     2.07
# 1      2.91  1.75      1.95      1.95   1.96   1.97     2.07     1.98
# 2      1.92 -0.50      1.95      1.95   1.98   1.95     2.00     1.96
# 3      1.71  0.00      1.87      2.03   1.89   2.03     1.90     2.07
# 4      1.71  0.25      1.82      2.08   1.97   1.96     2.03     2.08
#
#    AvgCAHH  AvgCAHA
# 0     1.90     1.99
# 1     1.97     1.92
# 2     1.96     1.92
# 3     1.86     2.02
# 4     1.96     1.93

# %% [markdown]
# # Data types

# %%
# convert columns to the best possible dtypes, object->string
df = df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1772 entries, 0 to 1771
# Columns: 103 entries, Div to AvgCAHA
# dtypes: Float64(79), Int64(16), string(8)
# memory usage: 1.6 MB

# %% [markdown]
# <a id="2.2.1"></a>
# # Format date features

# %%
# Cast date columns to the Date data type
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1772 entries, 0 to 1771
# Columns: 103 entries, Div to AvgCAHA
# dtypes: Float64(79), Int64(16), datetime64[ns](1), string(7)
# memory usage: 1.6 MB

# %% [markdown]
# # DROP NA & DUPLICATION
#
# + world_cup dataframe: year is the primary key
#
# + world_cup_match dataframe: year,match_id are the primary key

# %%
print("Number of rows before drop of duplicates in National Leagues:", len(df.index))
print("Number of duplicated records in National Leagues: ", df.duplicated().sum())
df = df.drop_duplicates(subset=['Div', 'Date', 'HomeTeam', 'AwayTeam'], keep="first")
print("Number of duplicated records AFTER DROP in National Leagues: ", df.duplicated().sum())
print("Number of rows after drop of duplicates in National Leagues:", len(df.index), "\n\n")
# Out:
# Number of rows before drop of duplicates in National Leagues: 1772
# Number of duplicated records in National Leagues:  0
# Number of duplicated records AFTER DROP in National Leagues:  0
# Number of rows after drop of duplicates in National Leagues: 1772

# %%
print("The National Leagues dataframe BEFORE dropped has {} rows and {} columns".format(df.shape[0], df.shape[1]))
df = df.dropna(subset=['Div', 'Date', 'HomeTeam', 'AwayTeam'])
# display missing values in descending
print("The National Leagues dataframe AFTER dropped has {} rows and {} columns".format(df.shape[0], df.shape[1]),"\n\n\n")
# Out:
# The National Leagues dataframe BEFORE dropped has 1772 rows and 103 columns
# The National Leagues dataframe AFTER dropped has 1772 rows and 103 columns

# %% [markdown]
# <a id="3"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong>3. Save the Intermediate data that has been transformed</strong></h1>

# %%
write_interim_path(df, '2019-2020.csv', 'national_leagues')
# Out:
# cleaned 2019-2020.csv data was successfully saved!
